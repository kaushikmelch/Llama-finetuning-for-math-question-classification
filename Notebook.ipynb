# %% [markdown]
# ## Llama finetuning to evaluate math questions - Deep Learning Midterm
#
# ### Kaushik Mellacheruvu
# ### Srirama Bulusu

# %% [markdown]
# Borrowed from [official Unsloth implementation](https://colab.research.google.com/drive/1Ys44kVvmeZtnICzWz0xgpRnrIOjZAuxp?usp=sharing#scrollTo=MKX_XKs_BNZR)

# %%
# %%capture
# This cell will take time
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth
#   Downloading unsloth-2024.11.7-py3-none-any.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 2.6 MB/s eta 0:00:00
# Collecting unsloth-zoo>=2024.11.1 (from unsloth)
#   Downloading unsloth_zoo-2024.11.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (2.5.1+cu121)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth) (24.2)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.46.2)
# Collecting datasets>=2.16.0 (from unsloth)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.45.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.1.1)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.12.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.13.2)
# Collecting protobuf<4.0.0 (from unsloth)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.26.2)
# Collecting hf-transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Collecting xxhash (from datasets>=2.16.0->unsloth)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->unsloth)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (0.20.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth) (0.2.0)
# Downloading unsloth-2024.11.7-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 6.2 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 21.4 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.9 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 9.1 MB/s eta 0:00:00
# Downloading trl-0.12.1-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.9/310.9 kB 12.5 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.11.5-py3-none-any.whl (31 kB)
# Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 82.3 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 13.8 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 12.5 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 8.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 10.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.1 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, triton, shtab, protobuf, hf-transfer, fsspec, dill, multiprocess, xformers, tyro, bitsandbytes, datasets, trl, unsloth-zoo, unsloth
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed bitsandbytes-0.44.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 hf-transfer-0.1.8 multiprocess-0.70.16 protobuf-3.20.3 shtab-1.7.1 triton-3.1.0 trl-0.12.1 tyro-0.8.14 unsloth-2024.11.7 unsloth-zoo-2024.11.5 xformers-0.0.28.post3 xxhash-3.5.0
# Found existing installation: unsloth 2024.11.7
# Uninstalling unsloth-2024.11.7:
#   Successfully uninstalled unsloth-2024.11.7
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-gsdps4ws/unsloth_e1cc5bec76424e08abdad543e362f280
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-gsdps4ws/unsloth_e1cc5bec76424e08abdad543e362f280
#   Resolved https://github.com/unslothai/unsloth.git to commit f26d4e739ed507de7a9088da53d10fd02f58d160
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth-zoo>=2024.11.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.14)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.46.2)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.26.2)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: bitsandbytes>=0.43.3 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.20.3)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.1.1)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.12.1)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.11.7-py3-none-any.whl size=163138 sha256=3c64b3b154594c65c9f00d2d77c0c5758c8c8963348d9428ce4e558fd8bb6be6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ovl9rvmy/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth
# Successfully installed unsloth-2024.11.7

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# ## Load model and wrap with LoRA adapters

# %% [markdown]
# The chosen LoRA adapters:
# 1. r = 64
# 2. lora_alpha = 64
# 3. use_rslora = True

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 64, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 64,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = True,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.11.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ## Competition dataset

# %%
# download and load competition dataset

from datasets import load_dataset
dataset = load_dataset("ad6398/nyu-dl-teach-maths-comp")
# print and see dataset
dataset
# Out:
# README.md:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 1000000
#     })
#     test: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 10000
#     })
# })

# %% [markdown]
# Updated the prompt to make the model understand.
# Added the solution as part of the prompt to give more context to the model for training

# %%
prompt = """You are a skilled mathematician. Your task is to assess the accuracy of a given answer to a math question based on the explanation provided. Carefully check both the answer and explanation. If both are correct, respond with 'True'. If either the answer or explanation is incorrect, respond with 'False'.

### Question:
{}

### Answer:
{}

### Explanation
{}

### Output:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    question = examples["question"]
    ans       = examples["answer"]
    output      = examples["is_correct"]
    solution = examples["solution"]
    texts = []
    for instruction, input, solution, output in zip(question, ans, solution, output):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = prompt.format(instruction, input, solution, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }

# %%
# Process the training dataset and generate prompt for each datapoint
train_dataset = dataset['train'].shuffle(seed=3407)
train_dataset = train_dataset.map(formatting_prompts_func, batched = True,)

train_valid_split = train_dataset.train_test_split(test_size=0.005, seed=3407)

# Access the splits
train_data = train_valid_split['train']
valid_data = train_valid_split['test']

print(f"Training data size: {len(train_data)}")
print(f"Validation data size: {len(valid_data)}")
# Out:
# Map:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Training data size: 995000
# Validation data size: 5000

# %%
#print a smaple training example
train_data['text'][0]
# Out:
# "You are a skilled mathematician. Your task is to assess the accuracy of a given answer to a math question based on the explanation provided. Carefully check both the answer and explanation. If both are correct, respond with 'True'. If either the answer or explanation is incorrect, respond with 'False'.\n\n### Question:\nMark is baking bread. He has to let it rise for 120 minutes twice. He also needs to spend 10 minutes kneading it and 30 minutes baking it. How many minutes does it take Mark to finish making the bread?\n\n### Answer:\n280\n\n### Explanation\nLet's solve this problem using Python's sympy library.\n<llm-code>\nimport sympy as sp\n\n# each rise takes 120 minutes\nrise_time_one = 120\nrise_time_two = 120\nrise_time = rise_time_one + rise_time_two\n\n# kneading takes 10 minutes and baking takes 30 minutes\nbaking_time = 30\nkneading_time = 10\n\n# add all times to get total time\ntotal_time = rise_time + kneading_time + baking_time\ntotal_time\n</llm-code>\n<llm-code-output>\n280\n</llm-code-output>\nThus it takes Mark \\boxed{280} minutes to finish baking the bread.\n\n### Output:\nTrue<|end_of_text|>"

# %% [markdown]
# ## SFT

# %% [markdown]
# The chosen parameters:
# 1. batch size = 4
# 2. gradient accumulation steps = 32
# 3. warm up steps = 40
# 4. max steps = 500

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

training_args = TrainingArguments(
        per_device_train_batch_size = 4,
        gradient_accumulation_steps = 32,
        warmup_steps = 40,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 500,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        eval_steps=50,  # Evaluate every 50 steps
        evaluation_strategy="steps",
        output_dir = "outputs",
        report_to="wandb",
        run_name="llama-finetuning-run"
    )

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset=train_data,
    eval_dataset=valid_data,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 4,
    packing = False, # Can make training 5x faster for short sequences.
    args = training_args
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# Initialize Wandb for tracking training and validation loss

# %%
import wandb
import os

wandb.init(
    project="llama-finetuning",
    entity="kaushikmelch-new-york-university",
    config={
        "learning_rate": 2e-4,
        "per_device_train_batch_size": 4,
        "gradient_accumulation_steps": 32,
        "max_steps": 500,
        "warmup_steps": 40,
    }
)
# Out:
# wandb: Currently logged in as: kaushikmelch (kaushikmelch-new-york-university). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/content/wandb/run-20241117_044559-nmnm0lay</code>
# Syncing run <strong><a href='https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning/runs/nmnm0lay' target="_blank">unique-tree-1</a></strong> to <a href='https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning' target="_blank">https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning</a>
#  View run at <a href='https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning/runs/nmnm0lay' target="_blank">https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning/runs/nmnm0lay</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/kaushikmelch-new-york-university/llama-finetuning/runs/nmnm0lay?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 995,000 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 32
# \        /    Total batch size = 128 | Total steps = 500
#  "-____-"     Number of trainable parameters = 167,772,160
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 3:47:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.634300</td>
#       <td>0.630645</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.582200</td>
#       <td>0.591511</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.548200</td>
#       <td>0.552570</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.530500</td>
#       <td>0.520559</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.509800</td>
#       <td>0.496463</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.464700</td>
#       <td>0.473250</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.456500</td>
#       <td>0.452602</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.456700</td>
#       <td>0.436098</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.431200</td>
#       <td>0.423860</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.450700</td>
#       <td>0.417399</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Log final stats
wandb.log({"final_loss": trainer_stats.training_loss})

# Save and upload the model to WandB
trainer.save_model("outputs/llama_finetuned_model")
artifact = wandb.Artifact("llama_model", type="model")
artifact.add_dir("outputs")
wandb.log_artifact(artifact)
# Out:
# wandb: Adding directory to artifact (./outputs)... Done. 10.6s
# <Artifact llama_model>

# %% [markdown]
# ## inference for one datapoint

# %%
# Sample inferene data point
test_dataset = dataset['test']

sample_ques = test_dataset['question'][0]
sample_ans = test_dataset['answer'][0]
sample_sol = test_dataset['solution'][0]

# %%
print(test_dataset[0])
# Out:
# {'question': 'The Parker family needs to leave the house by 5 pm for a dinner party. Mrs. Parker was waiting to get into the bathroom at 2:30 pm. Her oldest daughter used the bathroom for 45 minutes and her youngest daughter used the bathroom for another 30 minutes. Then her husband used it for 20 minutes. How much time will Mrs. Parker have to use the bathroom to leave on time?', 'is_correct': True, 'answer': '205', 'solution': "Let's solve this problem using Python code.\n<llm-code>\nminutes_per_hour = 60\nminutes_left_before_5 = 5 * minutes_per_hour\ntotal_time_spent_by_family = 45 + 30 + 20\nminutes_before_5_after_family = minutes_left_before_5 - total_time_spent_by_family\nminutes_before_5_after_family\n</llm-code>\n<llm-code-output>\n205\n</llm-code-output>\nThus Mrs. Parker will have \\boxed{205} minutes in the bathroom before the family leaves."}

# %%
# Running inference on single test
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
input_prompt = prompt.format(
        sample_ques, # ques
        sample_ans, # given answer
        sample_sol,
        "", # output - leave this blank for generation! LLM willl generate is it is True or False
    )

print("Input Promt:\n", input_prompt)
inputs = tokenizer(
[
    input_prompt
], return_tensors = "pt").to("cuda")

input_shape = inputs['input_ids'].shape
input_token_len = input_shape[1] # 1 because of batch
outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
# you can get the whole generated text by uncommenting the below line
# text_generated = tokenizer.batch_decode([outputs, skip_special_tokens=True)

response = tokenizer.batch_decode([outputs[0][input_token_len:]], skip_special_tokens=True)
response
# Out:
# Input Promt:
#  You are a skilled mathematician. Your task is to assess the accuracy of a given answer to a math question based on the explanation provided. Carefully check both the answer and explanation. If both are correct, respond with 'True'. If either the answer or explanation is incorrect, respond with 'False'.
#
# ### Question:
# The Parker family needs to leave the house by 5 pm for a dinner party. Mrs. Parker was waiting to get into the bathroom at 2:30 pm. Her oldest daughter used the bathroom for 45 minutes and her youngest daughter used the bathroom for another 30 minutes. Then her husband used it for 20 minutes. How much time will Mrs. Parker have to use the bathroom to leave on time?
#
# ### Answer:
# 205
#
# ### Explanation
# Let's solve this problem using Python code.
# <llm-code>
# minutes_per_hour = 60
# minutes_left_before_5 = 5 * minutes_per_hour
# total_time_spent_by_family = 45 + 30 + 20
# minutes_before_5_after_family = minutes_left_before_5 - total_time_spent_by_family
# minutes_before_5_after_family
# </llm-code>
# <llm-code-output>
# 205
# </llm-code-output>
# Thus Mrs. Parker will have \boxed{205} minutes in the bathroom before the family leaves.
#
# ### Output:
# ['True']

# %% [markdown]
# ## saving model

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %%
if True:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %% [markdown]
# ## Inference for entire test dataset

# %%
import gc
def clear_gpu_memory():
    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.synchronize()

# %% [markdown]
# Batching the data into 16 for faster evaluation

# %%
import pandas as pd

batch_size = 16
results = []

for start_idx in range(0, len(test_dataset), batch_size):
    batch = test_dataset.select(range(start_idx, min(start_idx + batch_size, len(test_dataset))))
    input_prompts = [
        prompt.format(entry['question'], entry['answer'], entry['solution'], "") for entry in batch
    ]
    inputs = tokenizer(input_prompts, return_tensors="pt", padding=True).to("cuda")
    input_token_lengths = [len(input_prompt) for input_prompt in inputs['input_ids']]


    outputs = model.generate(**inputs, max_new_tokens=64, use_cache=True)
    generated_responses = [
        tokenizer.decode(output[input_len:], skip_special_tokens=True).strip()
        for output, input_len in zip(outputs, input_token_lengths)
    ]

    for idx, (entry, response) in enumerate(zip(batch, generated_responses)):
        is_correct = response.lower() == str(entry['is_correct']).lower()
        results.append((start_idx + idx, bool(is_correct)))

    print(f"Processed batch starting at index {start_idx}")
    clear_gpu_memory()


df = pd.DataFrame(results, columns=["ID", "is_correct"])
df.to_csv("inference_results.csv", index=False)

print("Inference complete. Results saved to inference_results.csv.")
# Out:
# Processed batch starting at index 0
# Processed batch starting at index 16
# Processed batch starting at index 32
# Processed batch starting at index 48
# Processed batch starting at index 64
# Processed batch starting at index 80
# Processed batch starting at index 96
# Processed batch starting at index 112
# Processed batch starting at index 128
# Processed batch starting at index 144
# Processed batch starting at index 160
# Processed batch starting at index 176
# Processed batch starting at index 192
# Processed batch starting at index 208
# Processed batch starting at index 224
# Processed batch starting at index 240
# Processed batch starting at index 256
# Processed batch starting at index 272
# Processed batch starting at index 288
# Processed batch starting at index 304
# Processed batch starting at index 320
# Processed batch starting at index 336
# Processed batch starting at index 352
# Processed batch starting at index 368
# Processed batch starting at index 384
# Processed batch starting at index 400
# Processed batch starting at index 416
# Processed batch starting at index 432
# Processed batch starting at index 448
# Processed batch starting at index 464
# Processed batch starting at index 480
# Processed batch starting at index 496
# Processed batch starting at index 512
# Processed batch starting at index 528
# Processed batch starting at index 544
# Processed batch starting at index 560
# Processed batch starting at index 576
# Processed batch starting at index 592
# Processed batch starting at index 608
# Processed batch starting at index 624
# Processed batch starting at index 640
# Processed batch starting at index 656
# Processed batch starting at index 672
# Processed batch starting at index 688
# Processed batch starting at index 704
# Processed batch starting at index 720
# Processed batch starting at index 736
# Processed batch starting at index 752
# Processed batch starting at index 768
# Processed batch starting at index 784
# Processed batch starting at index 800
# Processed batch starting at index 816
# Processed batch starting at index 832
# Processed batch starting at index 848
# Processed batch starting at index 864
# Processed batch starting at index 880
# Processed batch starting at index 896
# Processed batch starting at index 912
# Processed batch starting at index 928
# Processed batch starting at index 944
# Processed batch starting at index 960
# Processed batch starting at index 976
# Processed batch starting at index 992
# Processed batch starting at index 1008
# Processed batch starting at index 1024
# Processed batch starting at index 1040
# Processed batch starting at index 1056
# Processed batch starting at index 1072
# Processed batch starting at index 1088
# Processed batch starting at index 1104
# Processed batch starting at index 1120
# Processed batch starting at index 1136
# Processed batch starting at index 1152
# Processed batch starting at index 1168
# Processed batch starting at index 1184
# Processed batch starting at index 1200
# Processed batch starting at index 1216
# Processed batch starting at index 1232
# Processed batch starting at index 1248
# Processed batch starting at index 1264
# Processed batch starting at index 1280
# Processed batch starting at index 1296
# Processed batch starting at index 1312
# Processed batch starting at index 1328
# Processed batch starting at index 1344
# Processed batch starting at index 1360
# Processed batch starting at index 1376
# Processed batch starting at index 1392
# Processed batch starting at index 1408
# Processed batch starting at index 1424
# Processed batch starting at index 1440
# Processed batch starting at index 1456
# Processed batch starting at index 1472
# Processed batch starting at index 1488
# Processed batch starting at index 1504
# Processed batch starting at index 1520
# Processed batch starting at index 1536
# Processed batch starting at index 1552
# Processed batch starting at index 1568
# Processed batch starting at index 1584
# Processed batch starting at index 1600
# Processed batch starting at index 1616
# Processed batch starting at index 1632
# Processed batch starting at index 1648
# Processed batch starting at index 1664
# Processed batch starting at index 1680
# Processed batch starting at index 1696
# Processed batch starting at index 1712
# Processed batch starting at index 1728
# Processed batch starting at index 1744
# Processed batch starting at index 1760
# Processed batch starting at index 1776
# Processed batch starting at index 1792
# Processed batch starting at index 1808
# Processed batch starting at index 1824
# Processed batch starting at index 1840
# Processed batch starting at index 1856
# Processed batch starting at index 1872
# Processed batch starting at index 1888
# Processed batch starting at index 1904
# Processed batch starting at index 1920
# Processed batch starting at index 1936
# Processed batch starting at index 1952
# Processed batch starting at index 1968
# Processed batch starting at index 1984
# Processed batch starting at index 2000
# Processed batch starting at index 2016
# Processed batch starting at index 2032
# Processed batch starting at index 2048
# Processed batch starting at index 2064
# Processed batch starting at index 2080
# Processed batch starting at index 2096
# Processed batch starting at index 2112
# Processed batch starting at index 2128
# Processed batch starting at index 2144
# Processed batch starting at index 2160
# Processed batch starting at index 2176
# Processed batch starting at index 2192
# Processed batch starting at index 2208
# Processed batch starting at index 2224
# Processed batch starting at index 2240
# Processed batch starting at index 2256
# Processed batch starting at index 2272
# Processed batch starting at index 2288
# Processed batch starting at index 2304
# Processed batch starting at index 2320
# Processed batch starting at index 2336
# Processed batch starting at index 2352
# Processed batch starting at index 2368
# Processed batch starting at index 2384
# Processed batch starting at index 2400
# Processed batch starting at index 2416
# Processed batch starting at index 2432
# Processed batch starting at index 2448
# Processed batch starting at index 2464
# Processed batch starting at index 2480
# Processed batch starting at index 2496
# Processed batch starting at index 2512
# Processed batch starting at index 2528
# Processed batch starting at index 2544
# Processed batch starting at index 2560
# Processed batch starting at index 2576
# Processed batch starting at index 2592
# Processed batch starting at index 2608
# Processed batch starting at index 2624
# Processed batch starting at index 2640
# Processed batch starting at index 2656
# Processed batch starting at index 2672
# Processed batch starting at index 2688
# Processed batch starting at index 2704
# Processed batch starting at index 2720
# Processed batch starting at index 2736
# Processed batch starting at index 2752
# Processed batch starting at index 2768
# Processed batch starting at index 2784
# Processed batch starting at index 2800
# Processed batch starting at index 2816
# Processed batch starting at index 2832
# Processed batch starting at index 2848
# Processed batch starting at index 2864
# Processed batch starting at index 2880
# Processed batch starting at index 2896
# Processed batch starting at index 2912
# Processed batch starting at index 2928
# Processed batch starting at index 2944
# Processed batch starting at index 2960
# Processed batch starting at index 2976
# Processed batch starting at index 2992
# Processed batch starting at index 3008
# Processed batch starting at index 3024
# Processed batch starting at index 3040
# Processed batch starting at index 3056
# Processed batch starting at index 3072
# Processed batch starting at index 3088
# Processed batch starting at index 3104
# Processed batch starting at index 3120
# Processed batch starting at index 3136
# Processed batch starting at index 3152
# Processed batch starting at index 3168
# Processed batch starting at index 3184
# Processed batch starting at index 3200
# Processed batch starting at index 3216
# Processed batch starting at index 3232
# Processed batch starting at index 3248
# Processed batch starting at index 3264
# Processed batch starting at index 3280
# Processed batch starting at index 3296
# Processed batch starting at index 3312
# Processed batch starting at index 3328
# Processed batch starting at index 3344
# Processed batch starting at index 3360
# Processed batch starting at index 3376
# Processed batch starting at index 3392
# Processed batch starting at index 3408
# Processed batch starting at index 3424
# Processed batch starting at index 3440
# Processed batch starting at index 3456
# Processed batch starting at index 3472
# Processed batch starting at index 3488
# Processed batch starting at index 3504
# Processed batch starting at index 3520
# Processed batch starting at index 3536
# Processed batch starting at index 3552
# Processed batch starting at index 3568
# Processed batch starting at index 3584
# Processed batch starting at index 3600
# Processed batch starting at index 3616
# Processed batch starting at index 3632
# Processed batch starting at index 3648
# Processed batch starting at index 3664
# Processed batch starting at index 3680
# Processed batch starting at index 3696
# Processed batch starting at index 3712
# Processed batch starting at index 3728
# Processed batch starting at index 3744
# Processed batch starting at index 3760
# Processed batch starting at index 3776
# Processed batch starting at index 3792
# Processed batch starting at index 3808
# Processed batch starting at index 3824
# Processed batch starting at index 3840
# Processed batch starting at index 3856
# Processed batch starting at index 3872
# Processed batch starting at index 3888
# Processed batch starting at index 3904
# Processed batch starting at index 3920
# Processed batch starting at index 3936
# Processed batch starting at index 3952
# Processed batch starting at index 3968
# Processed batch starting at index 3984
# Processed batch starting at index 4000
# Processed batch starting at index 4016
# Processed batch starting at index 4032
# Processed batch starting at index 4048
# Processed batch starting at index 4064
# Processed batch starting at index 4080
# Processed batch starting at index 4096
# Processed batch starting at index 4112
# Processed batch starting at index 4128
# Processed batch starting at index 4144
# Processed batch starting at index 4160
# Processed batch starting at index 4176
# Processed batch starting at index 4192
# Processed batch starting at index 4208
# Processed batch starting at index 4224
# Processed batch starting at index 4240
# Processed batch starting at index 4256
# Processed batch starting at index 4272
# Processed batch starting at index 4288
# Processed batch starting at index 4304
# Processed batch starting at index 4320
# Processed batch starting at index 4336
# Processed batch starting at index 4352
# Processed batch starting at index 4368
# Processed batch starting at index 4384
# Processed batch starting at index 4400
# Processed batch starting at index 4416
# Processed batch starting at index 4432
# Processed batch starting at index 4448
# Processed batch starting at index 4464
# Processed batch starting at index 4480
# Processed batch starting at index 4496
# Processed batch starting at index 4512
# Processed batch starting at index 4528
# Processed batch starting at index 4544
# Processed batch starting at index 4560
# Processed batch starting at index 4576
# Processed batch starting at index 4592
# Processed batch starting at index 4608
# Processed batch starting at index 4624
# Processed batch starting at index 4640
# Processed batch starting at index 4656
# Processed batch starting at index 4672
# Processed batch starting at index 4688
# Processed batch starting at index 4704
# Processed batch starting at index 4720
# Processed batch starting at index 4736
# Processed batch starting at index 4752
# Processed batch starting at index 4768
# Processed batch starting at index 4784
# Processed batch starting at index 4800
# Processed batch starting at index 4816
# Processed batch starting at index 4832
# Processed batch starting at index 4848
# Processed batch starting at index 4864
# Processed batch starting at index 4880
# Processed batch starting at index 4896
# Processed batch starting at index 4912
# Processed batch starting at index 4928
# Processed batch starting at index 4944
# Processed batch starting at index 4960
# Processed batch starting at index 4976
# Processed batch starting at index 4992
# Processed batch starting at index 5008
# Processed batch starting at index 5024
# Processed batch starting at index 5040
# Processed batch starting at index 5056
# Processed batch starting at index 5072
# Processed batch starting at index 5088
# Processed batch starting at index 5104
# Processed batch starting at index 5120
# Processed batch starting at index 5136
# Processed batch starting at index 5152
# Processed batch starting at index 5168
# Processed batch starting at index 5184
# Processed batch starting at index 5200
# Processed batch starting at index 5216
# Processed batch starting at index 5232
# Processed batch starting at index 5248
# Processed batch starting at index 5264
# Processed batch starting at index 5280
# Processed batch starting at index 5296
# Processed batch starting at index 5312
# Processed batch starting at index 5328
# Processed batch starting at index 5344
# Processed batch starting at index 5360
# Processed batch starting at index 5376
# Processed batch starting at index 5392
# Processed batch starting at index 5408
# Processed batch starting at index 5424
# Processed batch starting at index 5440
# Processed batch starting at index 5456
# Processed batch starting at index 5472
# Processed batch starting at index 5488
# Processed batch starting at index 5504
# Processed batch starting at index 5520
# Processed batch starting at index 5536
# Processed batch starting at index 5552
# Processed batch starting at index 5568
# Processed batch starting at index 5584
# Processed batch starting at index 5600
# Processed batch starting at index 5616
# Processed batch starting at index 5632
# Processed batch starting at index 5648
# Processed batch starting at index 5664
# Processed batch starting at index 5680
# Processed batch starting at index 5696
# Processed batch starting at index 5712
# Processed batch starting at index 5728
# Processed batch starting at index 5744
# Processed batch starting at index 5760
# Processed batch starting at index 5776
# Processed batch starting at index 5792
# Processed batch starting at index 5808
# Processed batch starting at index 5824
# Processed batch starting at index 5840
# Processed batch starting at index 5856
# Processed batch starting at index 5872
# Processed batch starting at index 5888
# Processed batch starting at index 5904
# Processed batch starting at index 5920
# Processed batch starting at index 5936
# Processed batch starting at index 5952
# Processed batch starting at index 5968
# Processed batch starting at index 5984
# Processed batch starting at index 6000
# Processed batch starting at index 6016
# Processed batch starting at index 6032
# Processed batch starting at index 6048
# Processed batch starting at index 6064
# Processed batch starting at index 6080
# Processed batch starting at index 6096
# Processed batch starting at index 6112
# Processed batch starting at index 6128
# Processed batch starting at index 6144
# Processed batch starting at index 6160
# Processed batch starting at index 6176
# Processed batch starting at index 6192
# Processed batch starting at index 6208
# Processed batch starting at index 6224
# Processed batch starting at index 6240
# Processed batch starting at index 6256
# Processed batch starting at index 6272
# Processed batch starting at index 6288
# Processed batch starting at index 6304
# Processed batch starting at index 6320
# Processed batch starting at index 6336
# Processed batch starting at index 6352
# Processed batch starting at index 6368
# Processed batch starting at index 6384
# Processed batch starting at index 6400
# Processed batch starting at index 6416
# Processed batch starting at index 6432
# Processed batch starting at index 6448
# Processed batch starting at index 6464
# Processed batch starting at index 6480
# Processed batch starting at index 6496
# Processed batch starting at index 6512
# Processed batch starting at index 6528
# Processed batch starting at index 6544
# Processed batch starting at index 6560
# Processed batch starting at index 6576
# Processed batch starting at index 6592
# Processed batch starting at index 6608
# Processed batch starting at index 6624
# Processed batch starting at index 6640
# Processed batch starting at index 6656
# Processed batch starting at index 6672
# Processed batch starting at index 6688
# Processed batch starting at index 6704
# Processed batch starting at index 6720
# Processed batch starting at index 6736
# Processed batch starting at index 6752
# Processed batch starting at index 6768
# Processed batch starting at index 6784
# Processed batch starting at index 6800
# Processed batch starting at index 6816
# Processed batch starting at index 6832
# Processed batch starting at index 6848
# Processed batch starting at index 6864
# Processed batch starting at index 6880
# Processed batch starting at index 6896
# Processed batch starting at index 6912
# Processed batch starting at index 6928
# Processed batch starting at index 6944
# Processed batch starting at index 6960
# Processed batch starting at index 6976
# Processed batch starting at index 6992
# Processed batch starting at index 7008
# Processed batch starting at index 7024
# Processed batch starting at index 7040
# Processed batch starting at index 7056
# Processed batch starting at index 7072
# Processed batch starting at index 7088
# Processed batch starting at index 7104
# Processed batch starting at index 7120
# Processed batch starting at index 7136
# Processed batch starting at index 7152
# Processed batch starting at index 7168
# Processed batch starting at index 7184
# Processed batch starting at index 7200
# Processed batch starting at index 7216
# Processed batch starting at index 7232
# Processed batch starting at index 7248
# Processed batch starting at index 7264
# Processed batch starting at index 7280
# Processed batch starting at index 7296
# Processed batch starting at index 7312
# Processed batch starting at index 7328
# Processed batch starting at index 7344
# Processed batch starting at index 7360
# Processed batch starting at index 7376
# Processed batch starting at index 7392
# Processed batch starting at index 7408
# Processed batch starting at index 7424
# Processed batch starting at index 7440
# Processed batch starting at index 7456
# Processed batch starting at index 7472
# Processed batch starting at index 7488
# Processed batch starting at index 7504
# Processed batch starting at index 7520
# Processed batch starting at index 7536
# Processed batch starting at index 7552
# Processed batch starting at index 7568
# Processed batch starting at index 7584
# Processed batch starting at index 7600
# Processed batch starting at index 7616
# Processed batch starting at index 7632
# Processed batch starting at index 7648
# Processed batch starting at index 7664
# Processed batch starting at index 7680
# Processed batch starting at index 7696
# Processed batch starting at index 7712
# Processed batch starting at index 7728
# Processed batch starting at index 7744
# Processed batch starting at index 7760
# Processed batch starting at index 7776
# Processed batch starting at index 7792
# Processed batch starting at index 7808
# Processed batch starting at index 7824
# Processed batch starting at index 7840
# Processed batch starting at index 7856
# Processed batch starting at index 7872
# Processed batch starting at index 7888
# Processed batch starting at index 7904
# Processed batch starting at index 7920
# Processed batch starting at index 7936
# Processed batch starting at index 7952
# Processed batch starting at index 7968
# Processed batch starting at index 7984
# Processed batch starting at index 8000
# Processed batch starting at index 8016
# Processed batch starting at index 8032
# Processed batch starting at index 8048
# Processed batch starting at index 8064
# Processed batch starting at index 8080
# Processed batch starting at index 8096
# Processed batch starting at index 8112
# Processed batch starting at index 8128
# Processed batch starting at index 8144
# Processed batch starting at index 8160
# Processed batch starting at index 8176
# Processed batch starting at index 8192
# Processed batch starting at index 8208
# Processed batch starting at index 8224
# Processed batch starting at index 8240
# Processed batch starting at index 8256
# Processed batch starting at index 8272
# Processed batch starting at index 8288
# Processed batch starting at index 8304
# Processed batch starting at index 8320
# Processed batch starting at index 8336
# Processed batch starting at index 8352
# Processed batch starting at index 8368
# Processed batch starting at index 8384
# Processed batch starting at index 8400
# Processed batch starting at index 8416
# Processed batch starting at index 8432
# Processed batch starting at index 8448
# Processed batch starting at index 8464
# Processed batch starting at index 8480
# Processed batch starting at index 8496
# Processed batch starting at index 8512
# Processed batch starting at index 8528
# Processed batch starting at index 8544
# Processed batch starting at index 8560
# Processed batch starting at index 8576
# Processed batch starting at index 8592
# Processed batch starting at index 8608
# Processed batch starting at index 8624
# Processed batch starting at index 8640
# Processed batch starting at index 8656
# Processed batch starting at index 8672
# Processed batch starting at index 8688
# Processed batch starting at index 8704
# Processed batch starting at index 8720
# Processed batch starting at index 8736
# Processed batch starting at index 8752
# Processed batch starting at index 8768
# Processed batch starting at index 8784
# Processed batch starting at index 8800
# Processed batch starting at index 8816
# Processed batch starting at index 8832
# Processed batch starting at index 8848
# Processed batch starting at index 8864
# Processed batch starting at index 8880
# Processed batch starting at index 8896
# Processed batch starting at index 8912
# Processed batch starting at index 8928
# Processed batch starting at index 8944
# Processed batch starting at index 8960
# Processed batch starting at index 8976
# Processed batch starting at index 8992
# Processed batch starting at index 9008
# Processed batch starting at index 9024
# Processed batch starting at index 9040
# Processed batch starting at index 9056
# Processed batch starting at index 9072
# Processed batch starting at index 9088
# Processed batch starting at index 9104
# Processed batch starting at index 9120
# Processed batch starting at index 9136
# Processed batch starting at index 9152
# Processed batch starting at index 9168
# Processed batch starting at index 9184
# Processed batch starting at index 9200
# Processed batch starting at index 9216
# Processed batch starting at index 9232
# Processed batch starting at index 9248
# Processed batch starting at index 9264
# Processed batch starting at index 9280
# Processed batch starting at index 9296
# Processed batch starting at index 9312
# Processed batch starting at index 9328
# Processed batch starting at index 9344
# Processed batch starting at index 9360
# Processed batch starting at index 9376
# Processed batch starting at index 9392
# Processed batch starting at index 9408
# Processed batch starting at index 9424
# Processed batch starting at index 9440
# Processed batch starting at index 9456
# Processed batch starting at index 9472
# Processed batch starting at index 9488
# Processed batch starting at index 9504
# Processed batch starting at index 9520
# Processed batch starting at index 9536
# Processed batch starting at index 9552
# Processed batch starting at index 9568
# Processed batch starting at index 9584
# Processed batch starting at index 9600
# Processed batch starting at index 9616
# Processed batch starting at index 9632
# Processed batch starting at index 9648
# Processed batch starting at index 9664
# Processed batch starting at index 9680
# Processed batch starting at index 9696
# Processed batch starting at index 9712
# Processed batch starting at index 9728
# Processed batch starting at index 9744
# Processed batch starting at index 9760
# Processed batch starting at index 9776
# Processed batch starting at index 9792
# Processed batch starting at index 9808
# Processed batch starting at index 9824
# Processed batch starting at index 9840
# Processed batch starting at index 9856
# Processed batch starting at index 9872
# Processed batch starting at index 9888
# Processed batch starting at index 9904
# Processed batch starting at index 9920
# Processed batch starting at index 9936
# Processed batch starting at index 9952
# Processed batch starting at index 9968
# Processed batch starting at index 9984
# Inference complete. Results saved to inference_results.csv.
